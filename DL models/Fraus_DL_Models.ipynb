# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

from BalanceDataset import *
from DeepLearningModels import *

# %%
df = pd.read_csv("creditcard.csv")

# Drop 'Time' column if present
if 'Time' in df.columns:
    df.drop('Time', axis=1, inplace=True)

# Remove outliers (Isolation Forest)
clf = IsolationForest(contamination=0.01, random_state=42)
mask = clf.fit_predict(df.drop("Class", axis=1)) != -1
df_cleaned = df[mask]

# %%
corr_matrix = df_cleaned.corr()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [col for col in upper.columns if any(upper[col].abs() > 0.95)]
df_selected = df_cleaned.drop(to_drop, axis=1)

# %%
# Check for NaNs in the 'Class' column and drop rows with NaNs
if df_selected['Class'].isnull().any():
    print("Warning: NaNs found in 'Class' column. Dropping rows with NaNs.")
    df_selected.dropna(subset=['Class'], inplace=True)

X = df_selected.drop("Class", axis=1)
y = df_selected["Class"]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Balance using SMOTE
X_train_bal, y_train_bal = balanceWithSMOTE(X_train_scaled, y_train)
# Out:
# Warning: NaNs found in 'Class' column. Dropping rows with NaNs.
# Non-Frauds: 34547 / 50.0 % of the dataset
# Frauds: 34547 / 50.0 % of the dataset

# %%
results = []

# ANN
results.append(ANN_model(X_train_bal, X_test_scaled, y_train_bal, y_test))

# CNN
results.append(CNN_model(X_train_bal, X_test_scaled, y_train_bal, y_test))

# RNN
results.append(RNN_model(X_train_bal, X_test_scaled, y_train_bal, y_test))

# LSTM
results.append(LSTM_model(X_train_bal, X_test_scaled, y_train_bal, y_test))

# Autoencoder
results.append(autoencoders(X_train_scaled, X_test_scaled, y_train, y_test))  # Uses original class imbalance
# Out:
# Epoch 1/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - auc: 0.9612 - loss: 0.2106 - precision: 0.8788 - recall: 0.9001 - val_auc: 0.0000e+00 - val_loss: 0.0089 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 2/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - auc: 1.0000 - loss: 0.0056 - precision: 0.9974 - recall: 0.9999 - val_auc: 0.0000e+00 - val_loss: 0.0024 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 3/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - auc: 1.0000 - loss: 0.0021 - precision: 0.9990 - recall: 1.0000 - val_auc: 0.0000e+00 - val_loss: 0.0013 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 4/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - auc: 1.0000 - loss: 0.0012 - precision: 0.9992 - recall: 1.0000 - val_auc: 0.0000e+00 - val_loss: 5.7835e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 5/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - auc: 1.0000 - loss: 8.9450e-04 - precision: 0.9995 - recall: 1.0000 - val_auc: 0.0000e+00 - val_loss: 7.2519e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 6/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - auc: 1.0000 - loss: 6.2097e-04 - precision: 0.9996 - recall: 1.0000 - val_auc: 0.0000e+00 - val_loss: 2.3140e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 7/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - auc: 1.0000 - loss: 2.9442e-04 - precision: 0.9999 - recall: 1.0000 - val_auc: 0.0000e+00 - val_loss: 2.1174e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 8/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - auc: 1.0000 - loss: 2.3079e-04 - precision: 0.9999 - recall: 1.0000 - val_auc: 0.0000e+00 - val_loss: 1.5829e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 9/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - auc: 1.0000 - loss: 1.2249e-04 - precision: 1.0000 - recall: 1.0000 - val_auc: 0.0000e+00 - val_loss: 7.9832e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 10/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 1.0000 - loss: 1.4442e-04 - precision: 1.0000 - recall: 1.0000 - val_auc: 0.0000e+00 - val_loss: 7.0685e-05 - val_precision: 1.0000 - val_recall: 1.0000
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - auc: 0.7147 - loss: 0.0074 - precision: 0.8640 - recall: 0.5548
# *************************************************
# F1 Score: 0.8571428571428571
# *************************************************
# Epoch 1/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - auc: 0.9979 - loss: 0.0924 - precision: 0.9473 - recall: 0.9719 - val_auc: 0.8730 - val_loss: 0.0078 - val_precision: 0.5455 - val_recall: 0.7500
# Epoch 2/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc: 0.9999 - loss: 0.0028 - precision: 0.9987 - recall: 1.0000 - val_auc: 0.8745 - val_loss: 0.0071 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 3/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - auc: 0.9999 - loss: 0.0022 - precision: 0.9993 - recall: 0.9999 - val_auc: 0.8733 - val_loss: 0.0100 - val_precision: 0.4286 - val_recall: 0.7500
# Epoch 4/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc: 0.9999 - loss: 0.0028 - precision: 0.9990 - recall: 0.9997 - val_auc: 0.8741 - val_loss: 0.0085 - val_precision: 0.5455 - val_recall: 0.7500
# Epoch 5/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - auc: 1.0000 - loss: 5.0446e-04 - precision: 0.9998 - recall: 1.0000 - val_auc: 0.8749 - val_loss: 0.0090 - val_precision: 1.0000 - val_recall: 0.6250
# Epoch 6/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - auc: 0.9999 - loss: 0.0016 - precision: 0.9995 - recall: 1.0000 - val_auc: 0.8746 - val_loss: 0.0090 - val_precision: 0.8571 - val_recall: 0.7500
# Epoch 7/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - auc: 1.0000 - loss: 1.6039e-04 - precision: 0.9999 - recall: 1.0000 - val_auc: 0.8748 - val_loss: 0.0093 - val_precision: 1.0000 - val_recall: 0.6250
# Epoch 8/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - auc: 1.0000 - loss: 7.3203e-04 - precision: 0.9997 - recall: 1.0000 - val_auc: 0.8124 - val_loss: 0.0120 - val_precision: 1.0000 - val_recall: 0.6250
# Epoch 9/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc: 1.0000 - loss: 5.0437e-04 - precision: 0.9999 - recall: 1.0000 - val_auc: 0.8745 - val_loss: 0.0105 - val_precision: 0.6667 - val_recall: 0.7500
# Epoch 10/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - auc: 1.0000 - loss: 0.0016 - precision: 0.9995 - recall: 0.9998 - val_auc: 0.8749 - val_loss: 0.0092 - val_precision: 1.0000 - val_recall: 0.6250
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - auc: 0.7148 - loss: 0.0119 - precision: 0.8640 - recall: 0.5007
# *************************************************
# F1 Score: 0.7692307692307693
# *************************************************
# Epoch 1/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - auc: 0.9939 - loss: 0.2618 - precision: 0.9071 - recall: 0.9578 - val_auc: 0.8885 - val_loss: 0.0240 - val_precision: 0.0968 - val_recall: 0.7500
# Epoch 2/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - auc: 0.9999 - loss: 0.0130 - precision: 0.9953 - recall: 1.0000 - val_auc: 0.8638 - val_loss: 0.0106 - val_precision: 0.1622 - val_recall: 0.7500
# Epoch 3/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - auc: 0.9999 - loss: 0.0057 - precision: 0.9980 - recall: 1.0000 - val_auc: 0.8692 - val_loss: 0.0071 - val_precision: 0.3333 - val_recall: 0.7500
# Epoch 4/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - auc: 1.0000 - loss: 0.0031 - precision: 0.9988 - recall: 1.0000 - val_auc: 0.8715 - val_loss: 0.0056 - val_precision: 0.4000 - val_recall: 0.7500
# Epoch 5/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - auc: 1.0000 - loss: 0.0021 - precision: 0.9992 - recall: 1.0000 - val_auc: 0.8730 - val_loss: 0.0046 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 6/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - auc: 1.0000 - loss: 0.0014 - precision: 0.9994 - recall: 1.0000 - val_auc: 0.8735 - val_loss: 0.0044 - val_precision: 0.5000 - val_recall: 0.7500
# Epoch 7/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - auc: 1.0000 - loss: 9.8719e-04 - precision: 0.9997 - recall: 1.0000 - val_auc: 0.8739 - val_loss: 0.0043 - val_precision: 0.5455 - val_recall: 0.7500
# Epoch 8/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - auc: 1.0000 - loss: 7.0413e-04 - precision: 0.9996 - recall: 1.0000 - val_auc: 0.8743 - val_loss: 0.0042 - val_precision: 0.6667 - val_recall: 0.7500
# Epoch 9/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - auc: 1.0000 - loss: 4.3299e-04 - precision: 1.0000 - recall: 1.0000 - val_auc: 0.8744 - val_loss: 0.0043 - val_precision: 0.6667 - val_recall: 0.7500
# Epoch 10/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - auc: 1.0000 - loss: 3.5723e-04 - precision: 0.9999 - recall: 1.0000 - val_auc: 0.8745 - val_loss: 0.0043 - val_precision: 0.6667 - val_recall: 0.7500
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - auc: 0.7143 - loss: 0.0051 - precision: 0.5563 - recall: 0.5548
# *************************************************
# F1 Score: 0.7058823640783763
# *************************************************
# Epoch 1/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - auc: 0.9964 - loss: 0.2580 - precision: 0.8966 - recall: 0.9838 - val_auc: 0.8814 - val_loss: 0.0172 - val_precision: 0.1765 - val_recall: 0.7500
# Epoch 2/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - auc: 0.9999 - loss: 0.0116 - precision: 0.9967 - recall: 1.0000 - val_auc: 0.8653 - val_loss: 0.0080 - val_precision: 0.2857 - val_recall: 0.7500
# Epoch 3/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - auc: 1.0000 - loss: 0.0048 - precision: 0.9981 - recall: 1.0000 - val_auc: 0.8702 - val_loss: 0.0059 - val_precision: 0.3529 - val_recall: 0.7500
# Epoch 4/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - auc: 1.0000 - loss: 0.0027 - precision: 0.9990 - recall: 1.0000 - val_auc: 0.8728 - val_loss: 0.0038 - val_precision: 0.5455 - val_recall: 0.7500
# Epoch 5/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - auc: 1.0000 - loss: 0.0020 - precision: 0.9993 - recall: 1.0000 - val_auc: 0.8733 - val_loss: 0.0037 - val_precision: 0.5455 - val_recall: 0.7500
# Epoch 6/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - auc: 1.0000 - loss: 0.0013 - precision: 0.9996 - recall: 1.0000 - val_auc: 0.8739 - val_loss: 0.0037 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 7/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - auc: 1.0000 - loss: 8.3589e-04 - precision: 0.9997 - recall: 1.0000 - val_auc: 0.8742 - val_loss: 0.0035 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 8/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - auc: 1.0000 - loss: 6.4648e-04 - precision: 0.9999 - recall: 1.0000 - val_auc: 0.8742 - val_loss: 0.0037 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 9/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - auc: 1.0000 - loss: 4.2261e-04 - precision: 0.9999 - recall: 1.0000 - val_auc: 0.8744 - val_loss: 0.0037 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 10/10
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - auc: 1.0000 - loss: 3.9421e-04 - precision: 0.9999 - recall: 1.0000 - val_auc: 0.8745 - val_loss: 0.0038 - val_precision: 0.6000 - val_recall: 0.7500
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - auc: 0.7142 - loss: 0.0045 - precision: 0.5666 - recall: 0.5548
# *************************************************
# F1 Score: 0.6666666813838626
# *************************************************
# Epoch 1/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - auc: 0.9581 - loss: -0.3426 - precision: 0.9999 - recall: 0.1331 - val_auc: 0.0000e+00 - val_loss: -5.5141 - val_precision: 1.0000 - val_recall: 0.0776
# Epoch 2/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.0000e+00 - loss: -9.2643 - precision: 1.0000 - recall: 0.0839 - val_auc: 0.0000e+00 - val_loss: -25.0124 - val_precision: 1.0000 - val_recall: 0.0932
# Epoch 3/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - auc: 0.0000e+00 - loss: -31.9461 - precision: 1.0000 - recall: 0.0946 - val_auc: 0.0000e+00 - val_loss: -58.0746 - val_precision: 1.0000 - val_recall: 0.0967
# Epoch 4/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.0000e+00 - loss: -67.2873 - precision: 1.0000 - recall: 0.0976 - val_auc: 0.0000e+00 - val_loss: -102.6979 - val_precision: 1.0000 - val_recall: 0.0981
# Epoch 5/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.0000e+00 - loss: -112.0832 - precision: 1.0000 - recall: 0.0985 - val_auc: 0.0000e+00 - val_loss: -157.2953 - val_precision: 1.0000 - val_recall: 0.0995
# Epoch 6/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - auc: 0.0000e+00 - loss: -169.1214 - precision: 1.0000 - recall: 0.0992 - val_auc: 0.0000e+00 - val_loss: -220.8370 - val_precision: 1.0000 - val_recall: 0.0998
# Epoch 7/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - auc: 0.0000e+00 - loss: -230.4863 - precision: 1.0000 - recall: 0.0995 - val_auc: 0.0000e+00 - val_loss: -292.8371 - val_precision: 1.0000 - val_recall: 0.1005
# Epoch 8/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.0000e+00 - loss: -307.7054 - precision: 1.0000 - recall: 0.1005 - val_auc: 0.0000e+00 - val_loss: -372.2558 - val_precision: 1.0000 - val_recall: 0.1008
# Epoch 9/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - auc: 0.0000e+00 - loss: -384.6765 - precision: 1.0000 - recall: 0.1011 - val_auc: 0.0000e+00 - val_loss: -459.7193 - val_precision: 1.0000 - val_recall: 0.1010
# Epoch 10/10
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.0000e+00 - loss: -471.9895 - precision: 1.0000 - recall: 0.1011 - val_auc: 0.0000e+00 - val_loss: -554.5591 - val_precision: 1.0000 - val_recall: 0.1013
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
df_results = pd.DataFrame(results, columns=["Model", "Precision", "Recall", "F1", "AUC"])
df_results.sort_values(by="F1", ascending=False).reset_index(drop=True)
# Out:
#          Model  Precision  Recall        F1       AUC
# 0          ANN   1.000000   0.750  0.857143  0.874812
# 1          CNN   1.000000   0.625  0.769231  0.874855
# 2          RNN   0.666667   0.750  0.705882  0.874493
# 3         LSTM   0.600000   0.750  0.666667  0.874450
# 4  Autoencoder   0.018767   0.875  0.036745  0.940843

# %%
import joblib

# %%
# Save cleaned dataset and scaler for DL
df_selected.to_csv("cleaned_dataset_dl.csv", index=False)
joblib.dump(scaler, "scaler_dl.pkl")
# Out:
# ['scaler_dl.pkl']
